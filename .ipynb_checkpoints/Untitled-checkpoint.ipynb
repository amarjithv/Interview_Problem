# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline
pd.options.display.max_columns = 200

# %%
data = pd.read_csv('Interview.csv')

# %%
data.shape
# Out:
# (1234, 28)

# %%
data = data.loc[:, ~data.columns.str.contains('^Unnamed')]

# %%
# Lets make the columns names easier to work with, by adding '_' where there's spaces. That way we invoke them as an object member
cols = data.columns
new_cols = []
for item in cols:
    new = item.replace(' ', '_')
    new_cols.append(new)
print(new_cols)
# Out:
# ['Date_of_Interview', 'Client_name', 'Industry', 'Location', 'Position_to_be_closed', 'Nature_of_Skillset', 'Interview_Type', 'Name(Cand_ID)', 'Gender', 'Candidate_Current_Location', 'Candidate_Job_Location', 'Interview_Venue', 'Candidate_Native_location', 'Have_you_obtained_the_necessary_permission_to_start_at_the_required_time', 'Hope_there_will_be_no_unscheduled_meetings', 'Can_I_Call_you_three_hours_before_the_interview_and_follow_up_on_your_attendance_for_the_interview', 'Can_I_have_an_alternative_number/_desk_number._I_assure_you_that_I_will_not_trouble_you_too_much', 'Have_you_taken_a_printout_of_your_updated_resume._Have_you_read_the_JD_and_understood_the_same', 'Are_you_clear_with_the_venue_details_and_the_landmark.', 'Has_the_call_letter_been_shared', 'Expected_Attendance', 'Observed_Attendance', 'Marital_Status']

# %%
data.columns = new_cols

# %%
data = data.drop('Date_of_Interview', axis=1).drop('Name(Cand_ID)', axis=1)

# %%
# Now lets see where we have missing values
data.isnull().sum()
# Out:
# Client_name                                                                                             0
# Industry                                                                                                1
# Location                                                                                                1
# Position_to_be_closed                                                                                   1
# Nature_of_Skillset                                                                                      1
# Interview_Type                                                                                          1
# Gender                                                                                                  1
# Candidate_Current_Location                                                                              1
# Candidate_Job_Location                                                                                  1
# Interview_Venue                                                                                         1
# Candidate_Native_location                                                                               1
# Have_you_obtained_the_necessary_permission_to_start_at_the_required_time                              205
# Hope_there_will_be_no_unscheduled_meetings                                                            248
# Can_I_Call_you_three_hours_before_the_interview_and_follow_up_on_your_attendance_for_the_interview    248
# Can_I_have_an_alternative_number/_desk_number._I_assure_you_that_I_will_not_trouble_you_too_much      248
# Have_you_taken_a_printout_of_your_updated_resume._Have_you_read_the_JD_and_understood_the_same        249
# Are_you_clear_with_the_venue_details_and_the_landmark.                                                249
# Has_the_call_letter_been_shared                                                                       246
# Expected_Attendance                                                                                     6
# Observed_Attendance                                                                                     1
# Marital_Status                                                                                          1
# dtype: int64

# %%
# But we also have some Nan values that are strings - 'Na', 'NA'
data.replace(to_replace=['Na', 'NA'], value=np.nan, inplace=True)

# %%
data.isnull().sum()
# Out:
# Client_name                                                                                             0
# Industry                                                                                                1
# Location                                                                                                1
# Position_to_be_closed                                                                                   1
# Nature_of_Skillset                                                                                      1
# Interview_Type                                                                                          1
# Gender                                                                                                  1
# Candidate_Current_Location                                                                              1
# Candidate_Job_Location                                                                                  1
# Interview_Venue                                                                                         1
# Candidate_Native_location                                                                               1
# Have_you_obtained_the_necessary_permission_to_start_at_the_required_time                              210
# Hope_there_will_be_no_unscheduled_meetings                                                            268
# Can_I_Call_you_three_hours_before_the_interview_and_follow_up_on_your_attendance_for_the_interview    268
# Can_I_have_an_alternative_number/_desk_number._I_assure_you_that_I_will_not_trouble_you_too_much      267
# Have_you_taken_a_printout_of_your_updated_resume._Have_you_read_the_JD_and_understood_the_same        268
# Are_you_clear_with_the_venue_details_and_the_landmark.                                                268
# Has_the_call_letter_been_shared                                                                       265
# Expected_Attendance                                                                                     6
# Observed_Attendance                                                                                     1
# Marital_Status                                                                                          1
# dtype: int64

# %%
data[data['Are_you_clear_with_the_venue_details_and_the_landmark.'].isnull()]
# Out:
#                   Client_name                  Industry   Location  \
# 2                     Hospira           Pharmaceuticals    Chennai
# 123   Standard Chartered Bank                      BFSI    Chennai
# 242   Standard Chartered Bank                      BFSI  Bangalore
# 243   Standard Chartered Bank                      BFSI  Bangalore
# 244   Standard Chartered Bank                      BFSI  Bangalore
# 245   Standard Chartered Bank                      BFSI  Bangalore
# 247   Standard Chartered Bank                      BFSI  Bangalore
# 248   Standard Chartered Bank                      BFSI  Bangalore
# 251   Standard Chartered Bank                      BFSI  Bangalore
# 254   Standard Chartered Bank                      BFSI  Bangalore
# 255   Standard Chartered Bank                      BFSI  Bangalore
# 260   Standard Chartered Bank                      BFSI  Bangalore
# 261   Standard Chartered Bank                      BFSI  Bangalore
# 264   Standard Chartered Bank                      BFSI  Bangalore
# 265   Standard Chartered Bank                      BFSI  Bangalore
# 267   Standard Chartered Bank                      BFSI  Bangalore
# 268   Standard Chartered Bank                      BFSI  Bangalore
# 269   Standard Chartered Bank                      BFSI  Bangalore
# 272   Standard Chartered Bank                      BFSI  Bangalore
# 273   Standard Chartered Bank                      BFSI  Bangalore
# 276   Standard Chartered Bank                      BFSI  Bangalore
# 279   Standard Chartered Bank                      BFSI  Bangalore
# 280   Standard Chartered Bank                      BFSI  Bangalore
# 283   Standard Chartered Bank                      BFSI  Bangalore
# 284   Standard Chartered Bank                      BFSI  Bangalore
# 286   Standard Chartered Bank                      BFSI  Bangalore
# 287   Standard Chartered Bank                      BFSI  Bangalore
# 289   Standard Chartered Bank                      BFSI  Bangalore
# 290   Standard Chartered Bank                      BFSI  Bangalore
# 292   Standard Chartered Bank                      BFSI  Bangalore
# ...                       ...                       ...        ...
# 937                   Prodapt                   Telecom    Chennai
# 938                   Prodapt                   Telecom    Chennai
# 1002               Aon Hewitt  IT Products and Services      Noida
# 1034  Standard Chartered Bank                      BFSI    Chennai
# 1042  Standard Chartered Bank                      BFSI  Bangalore
# 1045  Standard Chartered Bank                      BFSI  Bangalore
# 1048  Standard Chartered Bank                      BFSI  Bangalore
# 1049  Standard Chartered Bank                      BFSI  Bangalore
# 1050  Standard Chartered Bank                      BFSI  Bangalore
# 1051  Standard Chartered Bank                      BFSI  Bangalore
# 1053  Standard Chartered Bank                      BFSI  Bangalore
# 1055  Standard Chartered Bank                      BFSI  Bangalore
# 1059  Standard Chartered Bank                      BFSI  Bangalore
# 1060  Standard Chartered Bank                      BFSI  Bangalore
# 1061  Standard Chartered Bank                      BFSI  Bangalore
# 1062  Standard Chartered Bank                      BFSI  Bangalore
# 1065  Standard Chartered Bank                      BFSI  Bangalore
# 1071  Standard Chartered Bank                      BFSI    Chennai
# 1076  Standard Chartered Bank                      BFSI    Chennai
# 1077  Standard Chartered Bank                      BFSI    Chennai
# 1080  Standard Chartered Bank                      BFSI    Chennai
# 1081  Standard Chartered Bank                      BFSI    Chennai
# 1082  Standard Chartered Bank                      BFSI    Chennai
# 1083  Standard Chartered Bank                      BFSI    Chennai
# 1084  Standard Chartered Bank                      BFSI    Chennai
# 1086  Standard Chartered Bank                      BFSI    Chennai
# 1087  Standard Chartered Bank                      BFSI    Chennai
# 1088  Standard Chartered Bank                      BFSI    Chennai
# 1232                   Pfizer           Pharmaceuticals    Chennai
# 1233                       ﻿﻿                       NaN        NaN
#
#      Position_to_be_closed          Nature_of_Skillset     Interview_Type  \
# 2      Production- Sterile                     Routine   Scheduled Walkin
# 123                Routine       Accounting Operations   Scheduled Walkin
# 242                Routine                 AML/KYC/CDD   Scheduled Walkin
# 243                Routine                 AML/KYC/CDD   Scheduled Walkin
# 244                Routine                 AML/KYC/CDD   Scheduled Walkin
# 245                Routine                 AML/KYC/CDD   Scheduled Walkin
# 247                Routine                 AML/KYC/CDD   Scheduled Walkin
# 248                Routine                 AML/KYC/CDD   Scheduled Walkin
# 251                Routine                 AML/KYC/CDD   Scheduled Walkin
# 254                Routine                 AML/KYC/CDD   Scheduled Walkin
# 255                Routine                 AML/KYC/CDD   Scheduled Walkin
# 260                Routine                 AML/KYC/CDD  Scheduled Walk In
# 261                Routine                 AML/KYC/CDD  Scheduled Walk In
# 264                Routine                 AML/KYC/CDD  Scheduled Walk In
# 265                Routine                 AML/KYC/CDD  Scheduled Walk In
# 267                Routine                 AML/KYC/CDD   Scheduled Walkin
# 268                Routine                 AML/KYC/CDD   Scheduled Walkin
# 269                Routine                 AML/KYC/CDD   Scheduled Walkin
# 272                Routine                 AML/KYC/CDD   Scheduled Walkin
# 273                Routine                 AML/KYC/CDD   Scheduled Walkin
# 276                Routine                 AML/KYC/CDD  Scheduled Walk In
# 279                Routine                 AML/KYC/CDD  Scheduled Walk In
# 280                Routine                 AML/KYC/CDD  Scheduled Walk In
# 283                Routine                 AML/KYC/CDD  Scheduled Walk In
# 284                Routine                 AML/KYC/CDD  Scheduled Walk In
# 286                Routine                 AML/KYC/CDD  Scheduled Walk In
# 287                Routine                 AML/KYC/CDD  Scheduled Walk In
# 289                Routine                 AML/KYC/CDD  Scheduled Walk In
# 290                Routine                 AML/KYC/CDD  Scheduled Walk In
# 292                Routine                 AML/KYC/CDD   Scheduled Walkin
# ...                    ...                         ...                ...
# 937                Routine              COTS Developer         Scheduled
# 938                Routine              COTS Developer         Scheduled
# 1002               Routine                   Java, SQL         Scheduled
# 1034               Routine                        SCCM         Scheduled
# 1042               Routine                         SAS         Scheduled
# 1045               Routine                         SAS         Scheduled
# 1048               Routine                         SAS         Scheduled
# 1049               Routine                         SAS         Scheduled
# 1050               Routine                         SAS         Scheduled
# 1051               Routine                         SAS         Scheduled
# 1053               Routine                         SAS         Scheduled
# 1055               Routine                         SAS         Scheduled
# 1059               Routine                         SAS         Scheduled
# 1060               Routine                         SAS         Scheduled
# 1061               Routine                         SAS         Scheduled
# 1062               Routine                         SAS         Scheduled
# 1065               Routine                         SAS         Scheduled
# 1071               Routine  JAVA/J2EE/Struts/Hibernate  Scheduled Walk In
# 1076               Routine  JAVA/J2EE/Struts/Hibernate  Scheduled Walk In
# 1077               Routine  JAVA/J2EE/Struts/Hibernate  Scheduled Walk In
# 1080               Routine  JAVA/J2EE/Struts/Hibernate  Scheduled Walk In
# 1081               Routine  JAVA/J2EE/Struts/Hibernate  Scheduled Walk In
# 1082               Routine  JAVA/J2EE/Struts/Hibernate  Scheduled Walk In
# 1083               Routine  JAVA/J2EE/Struts/Hibernate  Scheduled Walk In
# 1084               Routine  JAVA/J2EE/Struts/Hibernate  Scheduled Walk In
# 1086               Routine  JAVA/J2EE/Struts/Hibernate  Scheduled Walk In
# 1087               Routine  JAVA/J2EE/Struts/Hibernate  Scheduled Walk In
# 1088               Routine  JAVA/J2EE/Struts/Hibernate  Scheduled Walk In
# 1232                 Niche          generic drugs – RA         Scheduled
# 1233                   NaN                         NaN                NaN
#
#       Gender Candidate_Current_Location Candidate_Job_Location  \
# 2       Male                    Chennai                Chennai
# 123   Female                    Chennai                Chennai
# 242     Male                  Bangalore              Bangalore
# 243   Female                  Bangalore              Bangalore
# 244     Male                  Bangalore              Bangalore
# 245     Male                  Bangalore              Bangalore
# 247   Female                  Bangalore              Bangalore
# 248   Female                  Bangalore              Bangalore
# 251     Male                  Bangalore              Bangalore
# 254     Male                  Bangalore              Bangalore
# 255     Male                  Bangalore              Bangalore
# 260     Male                  Bangalore              Bangalore
# 261     Male                  Bangalore              Bangalore
# 264     Male                  Bangalore              Bangalore
# 265   Female                  Bangalore              Bangalore
# 267     Male                  Bangalore              Bangalore
# 268     Male                  Bangalore              Bangalore
# 269     Male                  Bangalore              Bangalore
# 272     Male                  Bangalore              Bangalore
# 273     Male                  Bangalore              Bangalore
# 276   Female                  Bangalore              Bangalore
# 279     Male                  Bangalore              Bangalore
# 280   Female                  Bangalore              Bangalore
# 283     Male                  Bangalore              Bangalore
# 284     Male                  Bangalore              Bangalore
# 286     Male                  Bangalore              Bangalore
# 287     Male                  Bangalore              Bangalore
# 289   Female                  Bangalore              Bangalore
# 290   Female                  Bangalore              Bangalore
# 292     Male                  Bangalore              Bangalore
# ...      ...                        ...                    ...
# 937     Male                    Chennai                Chennai
# 938     Male                    Chennai                Chennai
# 1002    Male                      Noida                  Noida
# 1034    Male                    Chennai                Chennai
# 1042    Male                  Bangalore              Bangalore
# 1045    Male                  Bangalore              Bangalore
# 1048    Male                  Bangalore              Bangalore
# 1049    Male                  Bangalore              Bangalore
# 1050    Male                  Bangalore              Bangalore
# 1051    Male                  Bangalore              Bangalore
# 1053    Male                  Bangalore              Bangalore
# 1055    Male                  Bangalore              Bangalore
# 1059    Male                  Bangalore              Bangalore
# 1060    Male                  Bangalore              Bangalore
# 1061    Male                  Bangalore              Bangalore
# 1062    Male                  Bangalore              Bangalore
# 1065  Female                  Bangalore              Bangalore
# 1071    Male                    Chennai                Chennai
# 1076    Male                    Chennai                Chennai
# 1077    Male                    Chennai                Chennai
# 1080    Male                    Chennai                Chennai
# 1081    Male                    Chennai                Chennai
# 1082  Female                    Chennai                Chennai
# 1083  Female                    Chennai                Chennai
# 1084    Male                    Chennai                Chennai
# 1086  Female                    Chennai                Chennai
# 1087    Male                    Chennai                Chennai
# 1088    Male                    Chennai                Chennai
# 1232  Female                    Chennai                Chennai
# 1233     NaN                        NaN                    NaN
#
#      Interview_Venue Candidate_Native_location  \
# 2              Hosur                   Chennai
# 123          Chennai                   Chennai
# 242        Bangalore                   Chennai
# 243        Bangalore                 Bangalore
# 244        Bangalore                   Chennai
# 245        Bangalore                   Chennai
# 247        Bangalore                 Allahabad
# 248        Bangalore                   Chennai
# 251        Bangalore                 Hyderabad
# 254        Bangalore                 Bangalore
# 255        Bangalore                 Allahabad
# 260        Bangalore                   Kolkata
# 261        Bangalore                 Hyderabad
# 264        Bangalore                   Chennai
# 265        Bangalore                   Chennai
# 267        Bangalore                   Kolkata
# 268        Bangalore                 Bangalore
# 269        Bangalore                   Kolkata
# 272        Bangalore                   Chennai
# 273        Bangalore                 Hyderabad
# 276        Bangalore                    Cochin
# 279        Bangalore                 Hyderabad
# 280        Bangalore                 Allahabad
# 283        Bangalore                 Bangalore
# 284        Bangalore                 Hyderabad
# 286        Bangalore                      Pune
# 287        Bangalore             Visakapatinam
# 289        Bangalore                   Belgaum
# 290        Bangalore                 Bangalore
# 292        Bangalore                    Cochin
# ...              ...                       ...
# 937          Chennai                 Bangalore
# 938          Chennai                   Chennai
# 1002           Noida                     Noida
# 1034         Chennai                   Chennai
# 1042       Bangalore                 Hyderabad
# 1045       Bangalore                   Chennai
# 1048       Bangalore                 Allahabad
# 1049       Bangalore                 Hyderabad
# 1050       Bangalore                     Salem
# 1051       Bangalore                   Kolkata
# 1053       Bangalore                   Cuttack
# 1055       Bangalore                 Bangalore
# 1059       Bangalore                     Noida
# 1060       Bangalore                 Bangalore
# 1061       Bangalore                   Cuttack
# 1062       Bangalore                 Hyderabad
# 1065       Bangalore                 Bangalore
# 1071         Chennai                 Hyderabad
# 1076         Chennai                 Hyderabad
# 1077         Chennai                   Cuttack
# 1080         Chennai             Visakapatinam
# 1081         Chennai                   Chennai
# 1082         Chennai                   Chennai
# 1083         Chennai                   Chennai
# 1084         Chennai                 Hyderabad
# 1086         Chennai                   Cuttack
# 1087         Chennai                   Chennai
# 1088         Chennai                 Hyderabad
# 1232         Chennai                   Kolkata
# 1233             NaN                       NaN
#
#      Have_you_obtained_the_necessary_permission_to_start_at_the_required_time  \
# 2                                                   NaN
# 123                                                  No
# 242                                                 NaN
# 243                                                  No
# 244                                                 NaN
# 245                                                 NaN
# 247                                                 NaN
# 248                                                 NaN
# 251                                                 NaN
# 254                                                 NaN
# 255                                                 NaN
# 260                                                 NaN
# 261                                                 NaN
# 264                                                 NaN
# 265                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 272                                                 NaN
# 273                                                 NaN
# 276                                                 NaN
# 279                                                 NaN
# 280                                                 NaN
# 283                                                 NaN
# 284                                                 NaN
# 286                                                 NaN
# 287                                                 NaN
# 289                                                  No
# 290                                                 NaN
# 292                                                 NaN
# ...                                                 ...
# 937                                                  No
# 938                                                  No
# 1002                                                NaN
# 1034                                                 No
# 1042                                                 No
# 1045                                                NaN
# 1048                                                NaN
# 1049                                                NaN
# 1050                                                NaN
# 1051                                                NaN
# 1053                                                NaN
# 1055                                                NaN
# 1059                                                NaN
# 1060                                                NaN
# 1061                                                NaN
# 1062                                                 No
# 1065                                                NaN
# 1071                                                NaN
# 1076                                                 No
# 1077                                                NaN
# 1080                                                NaN
# 1081                                                NaN
# 1082                                                 No
# 1083                                                NaN
# 1084                                                 No
# 1086                                                NaN
# 1087                                                NaN
# 1088                                                NaN
# 1232                                                NaN
# 1233                                                NaN
#
#      Hope_there_will_be_no_unscheduled_meetings  \
# 2                                           NaN
# 123                                         Yes
# 242                                         NaN
# 243                                         NaN
# 244                                         NaN
# 245                                         NaN
# 247                                         NaN
# 248                                         NaN
# 251                                         NaN
# 254                                         NaN
# 255                                         NaN
# 260                                         NaN
# 261                                         NaN
# 264                                         NaN
# 265                                         NaN
# 267                                         NaN
# 268                                         NaN
# 269                                         NaN
# 272                                         NaN
# 273                                         NaN
# 276                                         NaN
# 279                                         NaN
# 280                                         NaN
# 283                                         NaN
# 284                                         NaN
# 286                                         NaN
# 287                                         NaN
# 289                                         NaN
# 290                                         NaN
# 292                                         NaN
# ...                                         ...
# 937                                         NaN
# 938                                         NaN
# 1002                                        NaN
# 1034                                        NaN
# 1042                                        NaN
# 1045                                        NaN
# 1048                                        NaN
# 1049                                        NaN
# 1050                                        NaN
# 1051                                        NaN
# 1053                                        NaN
# 1055                                        NaN
# 1059                                        NaN
# 1060                                        NaN
# 1061                                        NaN
# 1062                                        NaN
# 1065                                        NaN
# 1071                                        NaN
# 1076                                        NaN
# 1077                                        NaN
# 1080                                        NaN
# 1081                                        NaN
# 1082                                        NaN
# 1083                                        NaN
# 1084                                        NaN
# 1086                                        NaN
# 1087                                        NaN
# 1088                                        NaN
# 1232                                        NaN
# 1233                                        NaN
#
#      Can_I_Call_you_three_hours_before_the_interview_and_follow_up_on_your_attendance_for_the_interview  \
# 2                                                   NaN
# 123                                                  No
# 242                                                 NaN
# 243                                                 NaN
# 244                                                 NaN
# 245                                                 NaN
# 247                                                 NaN
# 248                                                 NaN
# 251                                                 NaN
# 254                                                 NaN
# 255                                                 NaN
# 260                                                 NaN
# 261                                                 NaN
# 264                                                 NaN
# 265                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 272                                                 NaN
# 273                                                 NaN
# 276                                                 NaN
# 279                                                 NaN
# 280                                                 NaN
# 283                                                 NaN
# 284                                                 NaN
# 286                                                 NaN
# 287                                                 NaN
# 289                                                 NaN
# 290                                                 NaN
# 292                                                 NaN
# ...                                                 ...
# 937                                                 NaN
# 938                                                 NaN
# 1002                                                NaN
# 1034                                                NaN
# 1042                                                NaN
# 1045                                                NaN
# 1048                                                NaN
# 1049                                                NaN
# 1050                                                NaN
# 1051                                                NaN
# 1053                                                NaN
# 1055                                                NaN
# 1059                                                NaN
# 1060                                                NaN
# 1061                                                NaN
# 1062                                                NaN
# 1065                                                NaN
# 1071                                                NaN
# 1076                                                NaN
# 1077                                                NaN
# 1080                                                NaN
# 1081                                                NaN
# 1082                                                NaN
# 1083                                                NaN
# 1084                                                NaN
# 1086                                                NaN
# 1087                                                NaN
# 1088                                                NaN
# 1232                                                NaN
# 1233                                                NaN
#
#      Can_I_have_an_alternative_number/_desk_number._I_assure_you_that_I_will_not_trouble_you_too_much  \
# 2                                                   NaN
# 123                                                  No
# 242                                                 NaN
# 243                                                 NaN
# 244                                                 NaN
# 245                                                 NaN
# 247                                                 NaN
# 248                                                 NaN
# 251                                                 NaN
# 254                                                 NaN
# 255                                                 NaN
# 260                                                 NaN
# 261                                                 NaN
# 264                                                 NaN
# 265                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 272                                                 NaN
# 273                                                 NaN
# 276                                                 NaN
# 279                                                 NaN
# 280                                                 NaN
# 283                                                 NaN
# 284                                                 NaN
# 286                                                 NaN
# 287                                                 NaN
# 289                                                 NaN
# 290                                                 NaN
# 292                                                 NaN
# ...                                                 ...
# 937                                                 NaN
# 938                                                 NaN
# 1002                                                NaN
# 1034                                                NaN
# 1042                                                NaN
# 1045                                                NaN
# 1048                                                NaN
# 1049                                                NaN
# 1050                                                NaN
# 1051                                                NaN
# 1053                                                NaN
# 1055                                                NaN
# 1059                                                NaN
# 1060                                                NaN
# 1061                                                NaN
# 1062                                                NaN
# 1065                                                NaN
# 1071                                                NaN
# 1076                                                NaN
# 1077                                                NaN
# 1080                                                NaN
# 1081                                                NaN
# 1082                                                NaN
# 1083                                                NaN
# 1084                                                NaN
# 1086                                                NaN
# 1087                                                NaN
# 1088                                                NaN
# 1232                                                NaN
# 1233                                                NaN
#
#      Have_you_taken_a_printout_of_your_updated_resume._Have_you_read_the_JD_and_understood_the_same  \
# 2                                                   NaN
# 123                                                 NaN
# 242                                                 NaN
# 243                                                 NaN
# 244                                                 NaN
# 245                                                 NaN
# 247                                                 NaN
# 248                                                 NaN
# 251                                                 NaN
# 254                                                 NaN
# 255                                                 NaN
# 260                                                 NaN
# 261                                                 NaN
# 264                                                 NaN
# 265                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 272                                                 NaN
# 273                                                 NaN
# 276                                                 NaN
# 279                                                 NaN
# 280                                                 NaN
# 283                                                 NaN
# 284                                                 NaN
# 286                                                 NaN
# 287                                                 NaN
# 289                                                 NaN
# 290                                                 NaN
# 292                                                 NaN
# ...                                                 ...
# 937                                                 NaN
# 938                                                 NaN
# 1002                                                NaN
# 1034                                                NaN
# 1042                                                NaN
# 1045                                                NaN
# 1048                                                NaN
# 1049                                                NaN
# 1050                                                NaN
# 1051                                                NaN
# 1053                                                NaN
# 1055                                                NaN
# 1059                                                NaN
# 1060                                                NaN
# 1061                                                NaN
# 1062                                                NaN
# 1065                                                NaN
# 1071                                                NaN
# 1076                                                NaN
# 1077                                                NaN
# 1080                                                NaN
# 1081                                                NaN
# 1082                                                NaN
# 1083                                                NaN
# 1084                                                NaN
# 1086                                                NaN
# 1087                                                NaN
# 1088                                                NaN
# 1232                                                NaN
# 1233                                                NaN
#
#      Are_you_clear_with_the_venue_details_and_the_landmark.  \
# 2                                                   NaN
# 123                                                 NaN
# 242                                                 NaN
# 243                                                 NaN
# 244                                                 NaN
# 245                                                 NaN
# 247                                                 NaN
# 248                                                 NaN
# 251                                                 NaN
# 254                                                 NaN
# 255                                                 NaN
# 260                                                 NaN
# 261                                                 NaN
# 264                                                 NaN
# 265                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 272                                                 NaN
# 273                                                 NaN
# 276                                                 NaN
# 279                                                 NaN
# 280                                                 NaN
# 283                                                 NaN
# 284                                                 NaN
# 286                                                 NaN
# 287                                                 NaN
# 289                                                 NaN
# 290                                                 NaN
# 292                                                 NaN
# ...                                                 ...
# 937                                                 NaN
# 938                                                 NaN
# 1002                                                NaN
# 1034                                                NaN
# 1042                                                NaN
# 1045                                                NaN
# 1048                                                NaN
# 1049                                                NaN
# 1050                                                NaN
# 1051                                                NaN
# 1053                                                NaN
# 1055                                                NaN
# 1059                                                NaN
# 1060                                                NaN
# 1061                                                NaN
# 1062                                                NaN
# 1065                                                NaN
# 1071                                                NaN
# 1076                                                NaN
# 1077                                                NaN
# 1080                                                NaN
# 1081                                                NaN
# 1082                                                NaN
# 1083                                                NaN
# 1084                                                NaN
# 1086                                                NaN
# 1087                                                NaN
# 1088                                                NaN
# 1232                                                NaN
# 1233                                                NaN
#
#      Has_the_call_letter_been_shared Expected_Attendance Observed_Attendance  \
# 2                                NaN           Uncertain                  No
# 123                     Yet to Check           Uncertain                 Yes
# 242                              NaN           Uncertain                 Yes
# 243                              NaN           Uncertain                  No
# 244                              NaN           Uncertain                  No
# 245                              NaN           Uncertain                 Yes
# 247                              NaN           Uncertain                  No
# 248                              NaN           Uncertain                 Yes
# 251                              NaN           Uncertain                 Yes
# 254                              NaN           Uncertain                  No
# 255                              NaN           Uncertain                  No
# 260                              NaN           Uncertain                 Yes
# 261                              NaN           Uncertain                  No
# 264                              NaN           Uncertain                 Yes
# 265                              NaN           Uncertain                  No
# 267                              NaN           Uncertain                  No
# 268                              NaN           Uncertain                 Yes
# 269                              NaN           Uncertain                  No
# 272                              NaN           Uncertain                 Yes
# 273                              NaN           Uncertain                 Yes
# 276                              NaN           Uncertain                  No
# 279                              NaN           Uncertain                  No
# 280                              NaN           Uncertain                 Yes
# 283                              NaN           Uncertain                  No
# 284                              NaN           Uncertain                 Yes
# 286                              NaN           Uncertain                 Yes
# 287                              NaN           Uncertain                  No
# 289                              NaN                  NO                  NO
# 290                              NaN           Uncertain                 Yes
# 292                              NaN           Uncertain                  No
# ...                              ...                 ...                 ...
# 937                              NaN                  No                  No
# 938                              NaN                  No                  No
# 1002                             NaN           Uncertain                 Yes
# 1034                              No                  No                  No
# 1042                              No                  No                  No
# 1045                             NaN                 NaN                 Yes
# 1048                             NaN                 NaN                 Yes
# 1049                             NaN                 NaN                  No
# 1050                             NaN                 NaN                 Yes
# 1051                             NaN                 NaN                  no
# 1053                             NaN           Uncertain                 yes
# 1055                             NaN           Uncertain                  No
# 1059                             NaN           Uncertain                 yes
# 1060                             NaN           Uncertain                 yes
# 1061                             NaN           Uncertain                  No
# 1062                             NaN                  No                  No
# 1065                             NaN           Uncertain                 Yes
# 1071                             NaN           Uncertain                  No
# 1076                             NaN           Uncertain                 yes
# 1077                             NaN           Uncertain                  No
# 1080                             NaN           Uncertain                 yes
# 1081                             NaN           Uncertain                  No
# 1082                             NaN           Uncertain                  No
# 1083                             NaN           Uncertain                 Yes
# 1084                             NaN           Uncertain                 yes
# 1086                             NaN           Uncertain                  No
# 1087                             NaN           Uncertain                 No
# 1088                             NaN           Uncertain                  No
# 1232                             NaN           Uncertain                 Yes
# 1233                             NaN                 NaN                 NaN
#
#      Marital_Status
# 2            Single
# 123          Single
# 242          Single
# 243          Single
# 244          Single
# 245         Married
# 247          Single
# 248          Single
# 251          Single
# 254          Single
# 255          Single
# 260          Single
# 261          Single
# 264         Married
# 265          Single
# 267          Single
# 268          Single
# 269         Married
# 272          Single
# 273         Married
# 276          Single
# 279         Married
# 280          Single
# 283          Single
# 284         Married
# 286          Single
# 287         Married
# 289         Married
# 290         Married
# 292         Married
# ...             ...
# 937          Single
# 938         Married
# 1002         Single
# 1034         Single
# 1042         Single
# 1045         Single
# 1048        Married
# 1049         Single
# 1050         Single
# 1051         Single
# 1053         Single
# 1055        Married
# 1059         Single
# 1060         Single
# 1061         Single
# 1062        Married
# 1065        Married
# 1071         Single
# 1076         Single
# 1077         Single
# 1080         Single
# 1081         Single
# 1082        Married
# 1083        Married
# 1084         Single
# 1086         Single
# 1087         Single
# 1088         Single
# 1232         Single
# 1233            NaN
#
# [268 rows x 21 columns]

# %%
# lets check what will happen if we drop the rows with Nan for the column that has the most Nan.
data[~data['Are_you_clear_with_the_venue_details_and_the_landmark.'].isnull()].isnull().sum()
# Out:
# Client_name                                                                                           0
# Industry                                                                                              0
# Location                                                                                              0
# Position_to_be_closed                                                                                 0
# Nature_of_Skillset                                                                                    0
# Interview_Type                                                                                        0
# Gender                                                                                                0
# Candidate_Current_Location                                                                            0
# Candidate_Job_Location                                                                                0
# Interview_Venue                                                                                       0
# Candidate_Native_location                                                                             0
# Have_you_obtained_the_necessary_permission_to_start_at_the_required_time                              0
# Hope_there_will_be_no_unscheduled_meetings                                                            1
# Can_I_Call_you_three_hours_before_the_interview_and_follow_up_on_your_attendance_for_the_interview    1
# Can_I_have_an_alternative_number/_desk_number._I_assure_you_that_I_will_not_trouble_you_too_much      0
# Have_you_taken_a_printout_of_your_updated_resume._Have_you_read_the_JD_and_understood_the_same        0
# Are_you_clear_with_the_venue_details_and_the_landmark.                                                0
# Has_the_call_letter_been_shared                                                                       0
# Expected_Attendance                                                                                   0
# Observed_Attendance                                                                                   0
# Marital_Status                                                                                        0
# dtype: int64

# %%
# Well that was easy....
data = data[~data['Are_you_clear_with_the_venue_details_and_the_landmark.'].isnull()]

# %%
# Lets drop the last row where we have Nan
data = data[~data['Hope_there_will_be_no_unscheduled_meetings'].isnull()]

# %%
data.isnull().sum()
# Out:
# Client_name                                                                                           0
# Industry                                                                                              0
# Location                                                                                              0
# Position_to_be_closed                                                                                 0
# Nature_of_Skillset                                                                                    0
# Interview_Type                                                                                        0
# Gender                                                                                                0
# Candidate_Current_Location                                                                            0
# Candidate_Job_Location                                                                                0
# Interview_Venue                                                                                       0
# Candidate_Native_location                                                                             0
# Have_you_obtained_the_necessary_permission_to_start_at_the_required_time                              0
# Hope_there_will_be_no_unscheduled_meetings                                                            0
# Can_I_Call_you_three_hours_before_the_interview_and_follow_up_on_your_attendance_for_the_interview    0
# Can_I_have_an_alternative_number/_desk_number._I_assure_you_that_I_will_not_trouble_you_too_much      0
# Have_you_taken_a_printout_of_your_updated_resume._Have_you_read_the_JD_and_understood_the_same        0
# Are_you_clear_with_the_venue_details_and_the_landmark.                                                0
# Has_the_call_letter_been_shared                                                                       0
# Expected_Attendance                                                                                   0
# Observed_Attendance                                                                                   0
# Marital_Status                                                                                        0
# dtype: int64

# %%
# Now lets clean out the data a little bit.....
data.nunique()
# Out:
# Client_name                                                                                           15
# Industry                                                                                               7
# Location                                                                                              11
# Position_to_be_closed                                                                                  7
# Nature_of_Skillset                                                                                    84
# Interview_Type                                                                                         5
# Gender                                                                                                 2
# Candidate_Current_Location                                                                            10
# Candidate_Job_Location                                                                                 7
# Interview_Venue                                                                                        7
# Candidate_Native_location                                                                             40
# Have_you_obtained_the_necessary_permission_to_start_at_the_required_time                               5
# Hope_there_will_be_no_unscheduled_meetings                                                             6
# Can_I_Call_you_three_hours_before_the_interview_and_follow_up_on_your_attendance_for_the_interview     4
# Can_I_have_an_alternative_number/_desk_number._I_assure_you_that_I_will_not_trouble_you_too_much       4
# Have_you_taken_a_printout_of_your_updated_resume._Have_you_read_the_JD_and_understood_the_same         6
# Are_you_clear_with_the_venue_details_and_the_landmark.                                                 5
# Has_the_call_letter_been_shared                                                                        9
# Expected_Attendance                                                                                    6
# Observed_Attendance                                                                                    8
# Marital_Status                                                                                         2
# dtype: int64

# %%
# Our label column Observed_Attendance has too many values - 'Yes' 'yes' 'YES etc...
data.Observed_Attendance.unique()
# Out:
# array(['No', 'Yes', 'yes', 'no', 'yes ', 'No ', 'NO', 'no '], dtype=object)

# %%
data.Observed_Attendance = data.Observed_Attendance.apply(lambda a: 1 if a in ['Yes', 'yes', 'yes '] else 0)
print(data.Observed_Attendance.unique())
# Out:
# [0 1]

# %%
# Same issue with Expected Attendance
data.Expected_Attendance.unique()
# Out:
# array(['Yes', 'Uncertain', 'No', 'yes', '11:00 AM', '10.30 Am'],
#       dtype=object)

# %%
data.Expected_Attendance = data.Expected_Attendance.apply(lambda a: 'Yes' if a in ['11:00 AM', '10.30 Am', 'yes'] else a)

# %%
data.Expected_Attendance.unique()
# Out:
# array(['Yes', 'Uncertain', 'No'], dtype=object)

# %%
data.Has_the_call_letter_been_shared.unique()
# Out:
# array(['Yes', 'Havent Checked', 'No', 'Need To Check', 'Not sure',
#        'Not Sure', 'Not yet', 'no', 'yes'], dtype=object)

# %%
data.Has_the_call_letter_been_shared = data.Has_the_call_letter_been_shared.apply(lambda a: 'Yes' if a in ['Yes', 'yes'] else ('No' if a in ['No', 'no'] else 'Maybe'))

# %%
data.nunique()
# Out:
# Client_name                                                                                           15
# Industry                                                                                               7
# Location                                                                                              11
# Position_to_be_closed                                                                                  7
# Nature_of_Skillset                                                                                    84
# Interview_Type                                                                                         5
# Gender                                                                                                 2
# Candidate_Current_Location                                                                            10
# Candidate_Job_Location                                                                                 7
# Interview_Venue                                                                                        7
# Candidate_Native_location                                                                             40
# Have_you_obtained_the_necessary_permission_to_start_at_the_required_time                               5
# Hope_there_will_be_no_unscheduled_meetings                                                             6
# Can_I_Call_you_three_hours_before_the_interview_and_follow_up_on_your_attendance_for_the_interview     4
# Can_I_have_an_alternative_number/_desk_number._I_assure_you_that_I_will_not_trouble_you_too_much       4
# Have_you_taken_a_printout_of_your_updated_resume._Have_you_read_the_JD_and_understood_the_same         6
# Are_you_clear_with_the_venue_details_and_the_landmark.                                                 5
# Has_the_call_letter_been_shared                                                                        3
# Expected_Attendance                                                                                    3
# Observed_Attendance                                                                                    2
# Marital_Status                                                                                         2
# dtype: int64

# %%
data['Are_you_clear_with_the_venue_details_and_the_landmark.'].unique()
# Out:
# array(['Yes', 'No', 'No- I need to check', 'yes', 'no'], dtype=object)

# %%
data['Are_you_clear_with_the_venue_details_and_the_landmark.'] = data['Are_you_clear_with_the_venue_details_and_the_landmark.'].apply(lambda a: 'Yes' if a in ['Yes', 'yes'] else 'No')

# %%
data['Have_you_taken_a_printout_of_your_updated_resume._Have_you_read_the_JD_and_understood_the_same'].unique()
# Out:
# array(['Yes', 'No', 'No- will take it soon', 'Not yet', 'yes', 'Not Yet'],
#       dtype=object)

# %%
data['Have_you_taken_a_printout_of_your_updated_resume._Have_you_read_the_JD_and_understood_the_same'] = data['Have_you_taken_a_printout_of_your_updated_resume._Have_you_read_the_JD_and_understood_the_same'].apply(lambda a: 'Yes' if a in ['Yes', 'yes'] else ('Not Yet' if a in ['Not Yet', 'Not yet'] else 'No'))
print(data['Have_you_taken_a_printout_of_your_updated_resume._Have_you_read_the_JD_and_understood_the_same'].unique())
# Out:
# ['Yes' 'No' 'Not Yet']

# %%
data['Can_I_have_an_alternative_number/_desk_number._I_assure_you_that_I_will_not_trouble_you_too_much'].unique()
# Out:
# array(['Yes', 'No', 'No I have only thi number', 'yes'], dtype=object)

# %%
data['Can_I_have_an_alternative_number/_desk_number._I_assure_you_that_I_will_not_trouble_you_too_much'] = data['Can_I_have_an_alternative_number/_desk_number._I_assure_you_that_I_will_not_trouble_you_too_much'].apply(lambda a: 'Yes' if a in ['Yes', 'yes'] else 'No')
data['Can_I_have_an_alternative_number/_desk_number._I_assure_you_that_I_will_not_trouble_you_too_much'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data['Can_I_Call_you_three_hours_before_the_interview_and_follow_up_on_your_attendance_for_the_interview'].unique()
# Out:
# array(['Yes', 'No', 'No Dont', 'yes'], dtype=object)

# %%
data['Can_I_Call_you_three_hours_before_the_interview_and_follow_up_on_your_attendance_for_the_interview'] = data['Can_I_Call_you_three_hours_before_the_interview_and_follow_up_on_your_attendance_for_the_interview'].apply(lambda a: 'Yes' if a in ['Yes', 'yes'] else 'No')
print(data['Can_I_Call_you_three_hours_before_the_interview_and_follow_up_on_your_attendance_for_the_interview'].unique())
# Out:
# ['Yes' 'No']

# %%
data['Hope_there_will_be_no_unscheduled_meetings'].unique()
# Out:
# array(['Yes', 'No', 'yes', 'Not Sure', 'cant Say', 'Not sure'],
#       dtype=object)

# %%
data['Hope_there_will_be_no_unscheduled_meetings'] = data['Hope_there_will_be_no_unscheduled_meetings'].apply(lambda a: 'Yes' if a in ['Yes', 'yes'] else ('No' if a == 'No' else 'Maybe'))
data['Hope_there_will_be_no_unscheduled_meetings'].unique()
# Out:
# array(['Yes', 'No', 'Maybe'], dtype=object)

# %%
data['Have_you_obtained_the_necessary_permission_to_start_at_the_required_time'].unique()
# Out:
# array(['Yes', 'No', 'Not yet', 'Yet to confirm', 'yes'], dtype=object)

# %%
data['Have_you_obtained_the_necessary_permission_to_start_at_the_required_time'] = data['Have_you_obtained_the_necessary_permission_to_start_at_the_required_time'].apply(lambda a: 'Yes' if a in ['Yes', 'yes'] else 'No')
data['Have_you_obtained_the_necessary_permission_to_start_at_the_required_time'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data.nunique()
# Out:
# Client_name                                                                                           15
# Industry                                                                                               7
# Location                                                                                              11
# Position_to_be_closed                                                                                  7
# Nature_of_Skillset                                                                                    84
# Interview_Type                                                                                         5
# Gender                                                                                                 2
# Candidate_Current_Location                                                                            10
# Candidate_Job_Location                                                                                 7
# Interview_Venue                                                                                        7
# Candidate_Native_location                                                                             40
# Have_you_obtained_the_necessary_permission_to_start_at_the_required_time                               2
# Hope_there_will_be_no_unscheduled_meetings                                                             3
# Can_I_Call_you_three_hours_before_the_interview_and_follow_up_on_your_attendance_for_the_interview     2
# Can_I_have_an_alternative_number/_desk_number._I_assure_you_that_I_will_not_trouble_you_too_much       2
# Have_you_taken_a_printout_of_your_updated_resume._Have_you_read_the_JD_and_understood_the_same         3
# Are_you_clear_with_the_venue_details_and_the_landmark.                                                 2
# Has_the_call_letter_been_shared                                                                        3
# Expected_Attendance                                                                                    3
# Observed_Attendance                                                                                    2
# Marital_Status                                                                                         2
# dtype: int64

# %%
for col in data:
    print('%s: ' % col, data[col].unique())
# Out:
# Client_name:  ['Hospira' 'Aon Hewitt' 'UST' 'Standard Chartered Bank' 'ANZ' 'Pfizer'
#  'Standard Chartered Bank Chennai' 'Aon hewitt Gurgaon' 'Astrazeneca'
#  'Flextronics' 'Prodapt' 'Williams Lea' 'Barclays' 'Hewitt' 'Woori Bank']
# Industry:  ['Pharmaceuticals' 'IT Services' 'BFSI' 'IT Products and Services'
#  'Electronics' 'Telecom' 'IT']
# Location:  ['Chennai' 'Gurgaon' 'Bangalore' 'Hyderabad' 'Gurgaonr' 'Delhi' 'chennai'
#  '- Cochin- ' 'Noida' 'CHENNAI' 'chennai ']
# Position_to_be_closed:  ['Production- Sterile' 'Selenium testing' 'Dot Net' 'AML' 'Trade Finance'
#  'Routine' 'Niche']
# Nature_of_Skillset:  ['Routine' 'Oracle' 'Accounting Operations' 'Banking Operations' 'Fresher'
#  'AML/KYC/CDD' 'CDD KYC' 'Biosimiliars' 'RA Label' 'RA Publishing' 'EMEA'
#  'generic drugs – RA' 'Regulatory' 'Analytical R & D' 'Analytical R&D'
#  'Senior software engineer-Mednet' 'Tech lead-Mednet' 'Tech Lead- Mednet'
#  'Technical Lead' 'TL' 'Sr Automation Testing' 'Senior Analyst'
#  'production' 'Core Java' 'Java J2EE' 'Oracle Plsql' 'Java,SQL'
#  'Automation Testing Java' 'Submission Management' 'Biosimillar'
#  'Publishing' 'Global Labelling' 'ALS Testing' 'Java Developer'
#  'Lending and Liabilities' 'Lending & Liability' 'Lending And Liabilities'
#  'L & L' 'Lending&Liablities' 'JAVA/J2EE/Struts/Hibernate'
#  'JAVA/SPRING/HIBERNATE/JSF' 'Java' 'Java,J2ee, JSF' 'Java ,J2ee'
#  'Java J2ee' '10.00 AM' '9.00 Am' '11.30 AM' '9.30 AM' 'Java,J2EE'
#  'Java/J2ee/Core Java' 'Java/J2ee' 'Java JSF' 'T-24 developer'
#  'COTS Developer' 'Product Control' 'Dot Net' 'COTS' 'testing'
#  '- SAPBO, Informatica' 'ETL' 'Java-SAS' 'Java Tech Lead' 'Manager'
#  'JAVA,SQL' 'Java, SQL' 'Hadoop' 'SCCM'
#  'SCCM-(Network, sharepoint,ms exchange)' 'SCCm- Desktop support'
#  'Sccm- networking' 'sccm' 'SCCM – SQL' 'SCCM – Sharepoint'
#  'Production Support - SCCM' 'SAS' 'BaseSAS Program/ Reporting'
#  'Java, Spring, Hibernate' 'Java,spring,hibernate'
#  'Java, XML, Struts, hibernate' 'JAVA/J2EE' 'Java ' 'LCM -Manager'
#  'Licensing – RA']
# Interview_Type:  ['Scheduled Walkin' 'Scheduled ' 'Walkin' 'Scheduled Walk In' 'Walkin ']
# Gender:  ['Male' 'Female']
# Candidate_Current_Location:  ['Chennai' 'Gurgaon' 'Bangalore' 'Hyderabad' 'Delhi' 'chennai'
#  '- Cochin- ' 'Noida' 'CHENNAI' 'chennai ']
# Candidate_Job_Location:  ['Hosur' 'Bangalore' 'Chennai' 'Gurgaon' 'Visakapatinam' '- Cochin- '
#  'Noida']
# Interview_Venue:  ['Hosur' 'Gurgaon' 'Bangalore' 'Chennai' 'Hyderabad' '- Cochin- ' 'Noida']
# Candidate_Native_location:  ['Hosur' 'Trichy' 'Chennai' 'Gurgaon' 'Noida' 'Delhi /NCR' 'Cochin'
#  'Trivandrum' 'Bangalore' 'Coimbatore' 'Salem' 'Tanjore' 'Hyderabad'
#  'Mumbai' 'Pune' 'Kolkata' 'Panjim' 'Allahabad' 'Cuttack' 'Visakapatinam'
#  'Anantapur' 'Ahmedabad' 'Kurnool' 'Vijayawada' 'Vellore' 'Pondicherry'
#  'Nagercoil' 'Chitoor' 'Agra' 'Tuticorin' 'Tirupati' 'Ambur' 'Chandigarh'
#  'Mysore' 'Hissar' 'Delhi' 'Kanpur' 'Lucknow' '- Cochin- ' 'Warangal']
# Have_you_obtained_the_necessary_permission_to_start_at_the_required_time:  ['Yes' 'No']
# Hope_there_will_be_no_unscheduled_meetings:  ['Yes' 'No' 'Maybe']
# Can_I_Call_you_three_hours_before_the_interview_and_follow_up_on_your_attendance_for_the_interview:  ['Yes' 'No']
# Can_I_have_an_alternative_number/_desk_number._I_assure_you_that_I_will_not_trouble_you_too_much:  ['Yes' 'No']
# Have_you_taken_a_printout_of_your_updated_resume._Have_you_read_the_JD_and_understood_the_same:  ['Yes' 'No' 'Not Yet']
# Are_you_clear_with_the_venue_details_and_the_landmark.:  ['Yes' 'No']
# Has_the_call_letter_been_shared:  ['Yes' 'Maybe' 'No']
# Expected_Attendance:  ['Yes' 'Uncertain' 'No']
# Observed_Attendance:  [0 1]
# Marital_Status:  ['Single' 'Married']

# %%
# Editing Industry
data.Industry.unique()
# Out:
# array(['Pharmaceuticals', 'IT Services', 'BFSI',
#        'IT Products and Services', 'Electronics', 'Telecom', 'IT'],
#       dtype=object)

# %%
data.Industry = data.Industry.apply(lambda a: 'IT' if a in ['IT Services', 'IT Products and Services', 'IT'] else a)
data.Industry.unique()
# Out:
# array(['Pharmaceuticals', 'IT', 'BFSI', 'Electronics', 'Telecom'],
#       dtype=object)

# %%
# Editing Location
data.Location.unique()
# Out:
# array(['Chennai', 'Gurgaon', 'Bangalore', 'Hyderabad', 'Gurgaonr',
#        'Delhi', 'chennai', '- Cochin- ', 'Noida', 'CHENNAI', 'chennai '],
#       dtype=object)

# %%
data.Location = data.Location.apply(lambda a: 'Gurgaon' if a in ['Gurgaon', 'Gurgaonr'] else ('Cochin' if a == '- Cochin- ' else a))
data.Location.unique()
# Out:
# array(['Chennai', 'Gurgaon', 'Bangalore', 'Hyderabad', 'Delhi', 'chennai',
#        'Cochin', 'Noida', 'CHENNAI', 'chennai '], dtype=object)

# %%
data.Location = data.Location.apply(lambda a: a.upper())
data.Location.unique()
# Out:
# array(['CHENNAI', 'GURGAON', 'BANGALORE', 'HYDERABAD', 'DELHI', 'COCHIN',
#        'NOIDA', 'CHENNAI '], dtype=object)

# %%
data.Location = data.Location.apply(lambda a: 'CHENNAI' if a in ['CHENNAI', 'CHENNAI '] else a)
data.Location.unique()
# Out:
# array(['CHENNAI', 'GURGAON', 'BANGALORE', 'HYDERABAD', 'DELHI', 'COCHIN',
#        'NOIDA'], dtype=object)

# %%
data.Nature_of_Skillset = data.Nature_of_Skillset.apply(lambda a: a.upper())

# %%
data.Nature_of_Skillset = data.Nature_of_Skillset.apply(lambda a: 'ANALYTICAL_R&D' if a in ['ANALYTICAL R & D', 'ANALYTICAL R&D'] else ('TECHNICAL_LEAD' if a in ['TECHNICAL LEAD', 'TL'] else a))

# %%
data.Nature_of_Skillset = data.Nature_of_Skillset.apply(lambda a: 'LENDING_LIABILITY' if a in ['LENDING AND LIABILITIES', 'LENDING & LIABILITY', 'L & L', 'LENDING&LIABLITIES'] else a)

# %%
data[data.Nature_of_Skillset.isin(['10.00 AM', '9.00 AM', '11.30 AM', '9.30 AM'])]
# Out:
#                  Client_name Industry Location Position_to_be_closed  \
# 817  Standard Chartered Bank     BFSI  CHENNAI               Routine
# 818  Standard Chartered Bank     BFSI  CHENNAI               Routine
# 820  Standard Chartered Bank     BFSI  CHENNAI               Routine
# 821  Standard Chartered Bank     BFSI  CHENNAI               Routine
#
#     Nature_of_Skillset     Interview_Type  Gender Candidate_Current_Location  \
# 817           10.00 AM  Scheduled Walk In    Male                    chennai
# 818            9.00 AM  Scheduled Walk In  Female                    chennai
# 820           11.30 AM  Scheduled Walk In    Male                    Chennai
# 821            9.30 AM  Scheduled Walk In    Male                    Chennai
#
#     Candidate_Job_Location Interview_Venue Candidate_Native_location  \
# 817                Chennai         Chennai                   Chennai
# 818                Chennai         Chennai                   Chennai
# 820                Chennai         Chennai                   Chennai
# 821                Chennai         Chennai                   Chennai
#
#     Have_you_obtained_the_necessary_permission_to_start_at_the_required_time  \
# 817                                                Yes
# 818                                                Yes
# 820                                                Yes
# 821                                                Yes
#
#     Hope_there_will_be_no_unscheduled_meetings  \
# 817                                        Yes
# 818                                        Yes
# 820                                        Yes
# 821                                        Yes
#
#     Can_I_Call_you_three_hours_before_the_interview_and_follow_up_on_your_attendance_for_the_interview  \
# 817                                                Yes
# 818                                                Yes
# 820                                                Yes
# 821                                                Yes
#
#     Can_I_have_an_alternative_number/_desk_number._I_assure_you_that_I_will_not_trouble_you_too_much  \
# 817                                                Yes
# 818                                                Yes
# 820                                                Yes
# 821                                                Yes
#
#     Have_you_taken_a_printout_of_your_updated_resume._Have_you_read_the_JD_and_understood_the_same  \
# 817                                                Yes
# 818                                                Yes
# 820                                                Yes
# 821                                                Yes
#
#     Are_you_clear_with_the_venue_details_and_the_landmark.  \
# 817                                                Yes
# 818                                                Yes
# 820                                                Yes
# 821                                                Yes
#
#     Has_the_call_letter_been_shared Expected_Attendance  Observed_Attendance  \
# 817                             Yes                 Yes                    0
# 818                             Yes                 Yes                    0
# 820                             Yes                 Yes                    1
# 821                             Yes                 Yes                    1
#
#     Marital_Status
# 817         Single
# 818        Married
# 820         Single
# 821         Single

# %%
# Lets drop these 4 lines....
data = data[~data.Nature_of_Skillset.isin(['10.00 AM', '9.00 AM', '11.30 AM', '9.30 AM'])]

# %%
# Grouping all the JAVA related entries
data.Nature_of_Skillset = data.Nature_of_Skillset.apply(lambda a: 'JAVA' if 'JAVA' in a else a)

# %%
# Same for SCCM
data.Nature_of_Skillset = data.Nature_of_Skillset.apply(lambda a: 'SCCM' if 'SCCM' in a else a)

# %%
data.Nature_of_Skillset = data.Nature_of_Skillset.apply(lambda a: 'AML/KYC/CDD' if a in ['AML/KYC/CDD', 'CDD KYC'] else a)

# %%
data.Nature_of_Skillset = data.Nature_of_Skillset.apply(lambda a: 'TECH_LEAD' if a in ['TECH LEAD-MEDNET', 'TECH LEAD- MEDNET', 'TECHNICAL_LEAD'] else a)

# %%
data.Nature_of_Skillset = data.Nature_of_Skillset.apply(lambda a: 'COTS' if 'COTS' in a else a)

# %%
data.nunique()
# Out:
# Client_name                                                                                           15
# Industry                                                                                               5
# Location                                                                                               7
# Position_to_be_closed                                                                                  7
# Nature_of_Skillset                                                                                    40
# Interview_Type                                                                                         5
# Gender                                                                                                 2
# Candidate_Current_Location                                                                            10
# Candidate_Job_Location                                                                                 7
# Interview_Venue                                                                                        7
# Candidate_Native_location                                                                             40
# Have_you_obtained_the_necessary_permission_to_start_at_the_required_time                               2
# Hope_there_will_be_no_unscheduled_meetings                                                             3
# Can_I_Call_you_three_hours_before_the_interview_and_follow_up_on_your_attendance_for_the_interview     2
# Can_I_have_an_alternative_number/_desk_number._I_assure_you_that_I_will_not_trouble_you_too_much       2
# Have_you_taken_a_printout_of_your_updated_resume._Have_you_read_the_JD_and_understood_the_same         3
# Are_you_clear_with_the_venue_details_and_the_landmark.                                                 2
# Has_the_call_letter_been_shared                                                                        3
# Expected_Attendance                                                                                    3
# Observed_Attendance                                                                                    2
# Marital_Status                                                                                         2
# dtype: int64

# %%
data.Interview_Type.unique()
# Out:
# array(['Scheduled Walkin', 'Scheduled ', 'Walkin', 'Scheduled Walk In',
#        'Walkin '], dtype=object)

# %%
# I assumed that a scheudle walkin is a like a scheduled interview....cause what ta hell is a scheduled walkin?
data.Interview_Type = data.Interview_Type.apply(lambda a: 'Scheduled' if 'Scheduled' in a else 'Walkin')

# %%
data.Candidate_Current_Location.unique()
# Out:
# array(['Chennai', 'Gurgaon', 'Bangalore', 'Hyderabad', 'Delhi', 'chennai',
#        '- Cochin- ', 'Noida', 'CHENNAI', 'chennai '], dtype=object)

# %%
data.Candidate_Current_Location = data.Candidate_Current_Location.apply(lambda a: (a.upper()).strip())
data.Candidate_Current_Location.unique()
# Out:
# array(['CHENNAI', 'GURGAON', 'BANGALORE', 'HYDERABAD', 'DELHI',
#        '- COCHIN-', 'NOIDA'], dtype=object)

# %%
print(data.Candidate_Job_Location.unique())
data.Candidate_Job_Location = data.Candidate_Job_Location.apply(lambda a: (a.upper()).strip())
print(data.Candidate_Job_Location.unique())
# Out:
# ['Hosur' 'Bangalore' 'Chennai' 'Gurgaon' 'Visakapatinam' '- Cochin- '
#  'Noida']
# ['HOSUR' 'BANGALORE' 'CHENNAI' 'GURGAON' 'VISAKAPATINAM' '- COCHIN-'
#  'NOIDA']

# %%
print(data.Interview_Venue.unique())
data.Interview_Venue = data.Interview_Venue.apply(lambda a: (a.upper()).strip())
print(data.Interview_Venue.unique())
# Out:
# ['Hosur' 'Gurgaon' 'Bangalore' 'Chennai' 'Hyderabad' '- Cochin- ' 'Noida']
# ['HOSUR' 'GURGAON' 'BANGALORE' 'CHENNAI' 'HYDERABAD' '- COCHIN-' 'NOIDA']

# %%
data.Candidate_Native_location = data.Candidate_Native_location.apply(lambda a: (a.upper()).strip())

# %%
data.Candidate_Native_location.unique()
# Out:
# array(['HOSUR', 'TRICHY', 'CHENNAI', 'GURGAON', 'NOIDA', 'DELHI /NCR',
#        'COCHIN', 'TRIVANDRUM', 'BANGALORE', 'COIMBATORE', 'SALEM',
#        'TANJORE', 'HYDERABAD', 'MUMBAI', 'PUNE', 'KOLKATA', 'PANJIM',
#        'ALLAHABAD', 'CUTTACK', 'VISAKAPATINAM', 'ANANTAPUR', 'AHMEDABAD',
#        'KURNOOL', 'VIJAYAWADA', 'VELLORE', 'PONDICHERRY', 'NAGERCOIL',
#        'CHITOOR', 'AGRA', 'TUTICORIN', 'TIRUPATI', 'AMBUR', 'CHANDIGARH',
#        'MYSORE', 'HISSAR', 'DELHI', 'KANPUR', 'LUCKNOW', '- COCHIN-',
#        'WARANGAL'], dtype=object)

# %%
data['is_interview_in_native_town'] = data.apply(lambda a: True if a.Candidate_Native_location == a.Interview_Venue else False, axis=1)

# %%
data['is_interview_in_current_town'] = data.apply(lambda a: True if a.Candidate_Current_Location == a.Interview_Venue else False, axis=1)

# %%
data['is_interview_in_current_job_town'] = data.apply(lambda a: True if a.Candidate_Job_Location == a.Interview_Venue else False, axis=1)

# %%
data['is_job_in_native_town'] = data.apply(lambda a: True if a.Location == a.Candidate_Native_location else False, axis=1)
data['is_job_in_current_twon'] = data.apply(lambda a: True if a.Candidate_Current_Location == a.Location else False, axis=1)
data['is_job_in_current_job_town'] = data.apply(lambda a: True if a.Candidate_Job_Location == a.Location else False, axis=1)

# %%
data.shape
# Out:
# (961, 27)

# %%
features, labels = data.loc[:, data.columns != 'Observed_Attendance'], data.loc[:, 'Observed_Attendance']

# %%
print(features.shape)
print(labels.shape)
# Out:
# (961, 26)
# (961,)

# %%
features_one_hot = pd.get_dummies(data=features)

# %%
features_one_hot.shape
# Out:
# (961, 167)

# %%
features_one_hot = features_one_hot.applymap(lambda a: 1 if a == True else (0 if a == False else 0))

# %%
from sklearn.model_selection import train_test_split

# %%
# Lets create our train, dev, and test sets
x_train, x_dev, y_train, y_dev = train_test_split(features_one_hot, labels, test_size=80, random_state=42)
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=80, random_state=42)

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.metrics import confusion_matrix

# %%
model = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=1), n_estimators=110, learning_rate=0.6)

# %%
model.fit(X=x_train, y=y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=0.6, n_estimators=110, random_state=None)

# %%
cross_validate(model, features_one_hot, labels, cv=5)
# Out:
# /home/amazingamar/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# {'fit_time': array([0.30439496, 0.25031877, 0.25311041, 0.37816763, 0.35428143]),
#  'score_time': array([0.01449609, 0.01427269, 0.01671219, 0.01732111, 0.01595998]),
#  'test_score': array([0.79274611, 0.546875  , 0.69791667, 0.765625  , 0.63541667]),
#  'train_score': array([0.74479167, 0.76723017, 0.77503251, 0.75162549, 0.77893368])}

# %%
test_preds = model.predict(x_test)

# %%
confusion_matrix(test_preds, y_test)
# Out:
# array([[ 5,  1],
#        [19, 55]])

# %%
#using bagging classifier
from sklearn.ensemble import BaggingClassifier
clf = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=1), n_estimators=110, learning_rate=0.6)
bagger = BaggingClassifier(base_estimator=clf, verbose=1, n_estimators=50)
bagger.fit(X=x_train, y=y_train)
# Out:
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   14.4s finished
# BaggingClassifier(base_estimator=AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=0.6, n_estimators=110, random_state=None),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=50, n_jobs=1, oob_score=False,
#          random_state=None, verbose=1, warm_start=False)

# %%
bagger.score(X=x_test, y=y_test)
# Out:
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s finished
# 0.75

# %%
preds = bagger.predict(x_test)
confusion_matrix(preds, y_test)
# Out:
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s finished
# array([[ 5,  1],
#        [19, 55]])

# %%
#Bagging is slower and does not seem to improve our scores
